# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('RAW_recipes.csv')

# %%
df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
df[['calories','total fat (PDV)','sugar (PDV)','sodium (PDV)','protein (PDV)','saturated fat (PDV)','carbohydrates (PDV)']] = df.nutrition.str.split(",",expand=True)

# %%
df['calories'] =  df['calories'].apply(lambda x: x.replace('[',''))

# %%
df['carbohydrates (PDV)'] =  df['carbohydrates (PDV)'].apply(lambda x: x.replace(']',''))

# %%
df[['calories','total fat (PDV)','sugar (PDV)','sodium (PDV)','protein (PDV)','saturated fat (PDV)','carbohydrates (PDV)']] = df[['calories','total fat (PDV)','sugar (PDV)','sodium (PDV)','protein (PDV)','saturated fat (PDV)','carbohydrates (PDV)']].astype('float')

# %%
df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  calories  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7      51.5
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6     173.4
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13     269.8
# 3  ['spreadable cheese with garlic and herbs', 'n...             11     368.1
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8     352.9
#
#    total fat (PDV)  sugar (PDV)  sodium (PDV)  protein (PDV)  \
# 0              0.0         13.0           0.0            2.0
# 1             18.0          0.0          17.0           22.0
# 2             22.0         32.0          48.0           39.0
# 3             17.0         10.0           2.0           14.0
# 4              1.0        337.0          23.0            3.0
#
#    saturated fat (PDV)  carbohydrates (PDV)
# 0                  0.0                  4.0
# 1                 35.0                  1.0
# 2                 27.0                  5.0
# 3                  8.0                 20.0
# 4                  0.0                 28.0

# %%
df.drop(['id', 'contributor_id','submitted','tags','nutrition'], axis=1,inplace = True)

# %%
df['food types'] = np.nan
df['food types'] = df['food types'].astype('str')

# %%
for i in df['ingredients'].index:
    if('eggs' not in df['ingredients'][i]):
         if('ice-cream' in df['ingredients'][i] or 'chocolate' in df['ingredients'][i] or 'cookies' in df['ingredients'][i]):
                df['food types'][i]='Veg dessert'
    elif('eggs' in df['ingredients'][i]):
        if('ice-cream' in df['ingredients'][i] or 'chocolate' in df['ingredients'][i] or 'cookies' in df['ingredients'][i]):
                df['food types'][i]='Non-Veg dessert'
# Out:
# C:\Users\Dylan Chen\AppData\Local\Temp\ipykernel_26696\2747373396.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['food types'][i]='Veg dessert'
# C:\Users\Dylan Chen\AppData\Local\Temp\ipykernel_26696\2747373396.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['food types'][i]='Non-Veg dessert'

# %%
for i in df.index:
    if(df['food types'][i]!='Veg dessert' and df['food types'][i]!='Non-Veg dessert' and 20<df['calories'][i]<300):
        df['food types'][i]='Healthy'
# Out:
# C:\Users\Dylan Chen\AppData\Local\Temp\ipykernel_26696\3090444994.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['food types'][i]='Healthy'

# %%
for i in df.index:
    if(df['food types'][i]!='Veg dessert' and df['food types'][i]!='Non-Veg dessert' and df['food types'][i]!='Healthy'):
        if('chicken' in df['ingredients'][i] or 'eggs' in df['ingredients'][i] or'ham' in df['ingredients'][i] or 'pepperoni' in df['ingredients'][i] or 'beef' in df['ingredients'][i] or 'pork' in df['ingredients'][i] or 'tri tip' in df['ingredients'][i]or 'turkey' in df['ingredients'][i]or 'duck' in df['ingredients'][i]or 'lamb' in df['ingredients'][i]or 'goat' in df['ingredients'][i]or 'bacon' in df['ingredients'][i]or 'sausage' in df['ingredients'][i]or 'salmon' in df['ingredients'][i]or 'salmon' in df['ingredients'][i]or 'fish' in df['ingredients'][i]or 'shrimp' in df['ingredients'][i]or 'tuna' in df['ingredients'][i]or 'crab' in df['ingredients'][i]or 'clams' in df['ingredients'][i]or 'mussel' in df['ingredients'][i]):
            df['food types'][i]='Non-veg'
# Out:
# C:\Users\Dylan Chen\AppData\Local\Temp\ipykernel_26696\158244437.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['food types'][i]='Non-veg'

# %%
for i in df.index:
    if(df['food types'][i]!='Veg dessert' and df['food types'][i]!='Non-Veg dessert' and df['food types'][i]!='Healthy' and df['food types'][i]!='Non-veg'):
        df['food types'][i]='Veg'
# Out:
# C:\Users\Dylan Chen\AppData\Local\Temp\ipykernel_26696\209991584.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['food types'][i]='Veg'

# %%
df.head()
# Out:
#                                          name  minutes  n_steps  \
# 0  arriba   baked winter squash mexican style       55       11
# 1            a bit different  breakfast pizza       30        9
# 2                   all in the kitchen  chili      130        6
# 3                          alouette  potatoes       45       11
# 4          amish  tomato ketchup  for canning      190        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  calories  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7      51.5
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6     173.4
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13     269.8
# 3  ['spreadable cheese with garlic and herbs', 'n...             11     368.1
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8     352.9
#
#    total fat (PDV)  sugar (PDV)  sodium (PDV)  protein (PDV)  \
# 0              0.0         13.0           0.0            2.0
# 1             18.0          0.0          17.0           22.0
# 2             22.0         32.0          48.0           39.0
# 3             17.0         10.0           2.0           14.0
# 4              1.0        337.0          23.0            3.0
#
#    saturated fat (PDV)  carbohydrates (PDV) food types
# 0                  0.0                  4.0    Healthy
# 1                 35.0                  1.0    Healthy
# 2                 27.0                  5.0    Healthy
# 3                  8.0                 20.0        Veg
# 4                  0.0                 28.0        Veg

# %%
df.to_csv("recipes.csv",index = False)

# %%
tempdf = df.sort_values('calories',ascending = False)
samp = tempdf.sample(n=10000)
samp.to_csv("10000_recipes.csv",index = False)

# %% [markdown]
# Code from: https://www.kaggle.com/code/aayushmishra1512/food-recommender
# database set:https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions?select=ingr_map.pkl
